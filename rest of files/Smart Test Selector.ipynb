# %%
import pandas as pd

# Create a dictionary with the data
data = {
    "Smart Test Selection Mechanism": [
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
        "Changed Code Selection",
        "Dependency-Based Selection",
        "Historical Failure Selection",
        "Coverage-Driven Selection",
        "Impact Analysis Selection",
        "Priority Queue Selection",
    ],
    "Code Changes": [
        "if x > 5:\n    result = x * 2\nelse:\n    result = x + 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM users\")",
        "def divide(a, b):\n    return a / b\n\ndef test_divide():\n    assert divide(4, 2) == 2\n    assert divide(1, 0) == 0",
        "class Calculator:\n    def add(self, a, b):\n        return a + b\n\ndef test_add():\n    calc = Calculator()\n    assert calc.add(2, 3) == 5\n\ndef test_subtract():\n    calc = Calculator()\n    assert calc.subtract(5, 3) == 2",
        "def process_data(data):\n    if data:\n        result = data[0] * 2\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n    \n    def enqueue(self, item):\n        self.items.append(item)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1",
        "for i in range(10):\n    if i % 2 == 0:\n        print(i)",
        "import os\n\ndef list_files(directory):\n    return os.listdir(directory)",
        "def calculate_average(numbers):\n    total = sum(numbers)\n    return total / len(numbers)\n\ndef test_calculate_average():\n    assert calculate_average([1, 2, 3]) == 2\n    assert calculate_average([4, 5, 6]) == 5",
        "class ShoppingCart:\n    def __init__(self):\n        self.items = []\n    \n    def add_item(self, item):\n        self.items.append(item)\n\ndef test_add_item():\n    cart = ShoppingCart()\n    cart.add_item(\"item1\")\n    assert \"item1\" in cart.items\n\ndef test_remove_item():\n    cart = ShoppingCart()\n    cart.add_item(\"item1\")\n    cart.remove_item(\"item1\")\n    assert \"item1\" not in cart.items",
        "def analyze_data(data):\n    if data:\n        result = max(data)\n    else:\n        result = 0",
        "class Stack:\n    def __init__(self):\n        self.items = []\n    \n    def push(self, item):\n        self.items.append(item)\n\ndef test_push():\n    stack = Stack()\n    stack.push(1)\n    assert stack.items == [1]\n\ndef test_pop():\n    stack = Stack()\n    stack.push(1)\n    assert stack.pop() == 1",
        "def is_prime(n):\n    if n <= 1:\n        return False\n    for i in range(2, int(n ** 0.5) + 1):\n        if n % i == 0:\n            return False\n    return True",
        "from datetime import datetime\n\ndef get_current_time():\n    return datetime.now()",
        "def reverse_string(s):\n    return s[::-1]\n\ndef test_reverse_string():\n    assert reverse_string(\"hello\") == \"olleh\"",
        "class Circle:\n    def __init__(self, radius):\n        self.radius = radius\n    \n    def area(self):\n        return 3.14 * self.radius ** 2\n\ndef test_area():\n    circle = Circle(5)\n    assert circle.area() == 78.5\n\ndef test_circumference():\n    circle = Circle(3)\n    assert circle.circumference() == 18.84",
        "def process_numbers(numbers):\n    if numbers:\n        result = sum(numbers)\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n    \n    def enqueue(self, item):\n        self.items.append(item)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1",
        "def calculate_square(n):\n    return n ** 2",
        "from math import sqrt\n\ndef calculate_sqrt(n):\n    return sqrt(n)",
        "def calculate_mean(numbers):\n    total = sum(numbers)\n    return total / len(numbers)\n\ndef test_calculate_mean():\n    assert calculate_mean([1, 2, 3]) == 2\n    assert calculate_mean([4, 5, 6]) == 5",
        "class Rectangle:\n    def __init__(self, length, width):\n        self.length = length\n        self.width = width\n    \n    def area(self):\n        return self.length * self.width\n\ndef test_area():\n    rectangle = Rectangle(4, 5)\n    assert rectangle.area() == 20\n\ndef test_perimeter():\n    rectangle = Rectangle(3, 6)\n    assert rectangle.perimeter() == 18",
        "def analyze_text(text):\n    if text:\n        result = len(text.split())\n    else:\n        result = 0",
        "class Stack:\n    def __init__(self):\n        self.items = []\n    \n    def push(self, item):\n        self.items.append(item)\n\ndef test_push():\n    stack = Stack()\n    stack.push(1)\n    assert stack.items == [1]\n\ndef test_pop():\n    stack = Stack()\n    stack.push(1)\n    assert stack.pop() == 1",
    ]
}

# Create a DataFrame from the dictionary
df = pd.DataFrame(data)

# Save as Excel file
df.to_excel("smart_test_selection.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 84
#       4 data = {
#       5     "Smart Test Selection Mechanism": [
#       6         "Changed Code Selection",
#    (...)
#      80     ]
#      81 }
#      83 # Create a DataFrame from the dictionary
# ---> 84 df = pd.DataFrame(data)
#      86 # Save as Excel file
#      87 df.to_excel("smart_test_selection.xlsx", index=False)
#
# File c:\Users\warun\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:709, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     703     mgr = self._init_mgr(
#     704         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     705     )
#     707 elif isinstance(data, dict):
#     708     # GH#38939 de facto copy defaults to False only in non-dict cases
# ...

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -cipy (c:\users\warun\anaconda3\envs\tensorflow\lib\site-packages)
# WARNING: Error parsing requirements for beautifulsoup4: [Errno 2] No such file or directory: 'c:\\users\\warun\\anaconda3\\envs\\tensorflow\\lib\\site-packages\\beautifulsoup4-4.12.0.dist-info\\METADATA'
# WARNING: Ignoring invalid distribution -cipy (c:\users\warun\anaconda3\envs\tensorflow\lib\site-packages)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Define the dataset
data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection", "Historical Failure Selection", "Coverage-Driven Selection", "Impact Analysis Selection", "Priority Queue Selection"],
    "Code Changes": [
        "if x > 5:\n    result = x * 2\nelse:\n    result = x + 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM users\")",
        "def divide(a, b):\n    return a / b\n\ndef test_divide():\n    assert divide(4, 2) == 2\n    assert divide(1, 0) == 0",
        "class Calculator:\n    def add(self, a, b):\n        return a + b\n\ndef test_add():\n    calc = Calculator()\n    assert calc.add(2, 3) == 5\n\ndef test_subtract():\n    calc = Calculator()\n    assert calc.subtract(5, 3) == 2",
        "def process_data(data):\n    if data:\n        result = data[0] * 2\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n\n    def enqueue(self, item):\n        self.items.append(item)\n\n    def dequeue(self):\n        return self.items.pop(0)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("test_dataset.xlsx", index=False, engine='openpyxl')
import pandas as pd

# Define the dataset
data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection", "Historical Failure Selection", "Coverage-Driven Selection", "Impact Analysis Selection", "Priority Queue Selection"],
    "Code Changes": [
        "if x > 5:\n    result = x * 2\nelse:\n    result = x + 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM users\")",
        "def divide(a, b):\n    return a / b\n\ndef test_divide():\n    assert divide(4, 2) == 2\n    assert divide(1, 0) == 0",
        "class Calculator:\n    def add(self, a, b):\n        return a + b\n\ndef test_add():\n    calc = Calculator()\n    assert calc.add(2, 3) == 5\n\ndef test_subtract():\n    calc = Calculator()\n    assert calc.subtract(5, 3) == 2",
        "def process_data(data):\n    if data:\n        result = data[0] * 2\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n\n    def enqueue(self, item):\n        self.items.append(item)\n\n    def dequeue(self):\n        return self.items.pop(0)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("test_dataset.xlsx", index=False, engine='openpyxl')

# %%
import pandas as pd

# Existing dataset
data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection", "Historical Failure Selection", "Coverage-Driven Selection", "Impact Analysis Selection", "Priority Queue Selection"],
    "Code Changes": [
        "if x > 5:\n    result = x * 2\nelse:\n    result = x + 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM users\")",
        "def divide(a, b):\n    return a / b\n\ndef test_divide():\n    assert divide(4, 2) == 2\n    assert divide(1, 0) == 0",
        "class Calculator:\n    def add(self, a, b):\n        return a + b\n\ndef test_add():\n    calc = Calculator()\n    assert calc.add(2, 3) == 5\n\ndef test_subtract():\n    calc = Calculator()\n    assert calc.subtract(5, 3) == 2",
        "def process_data(data):\n    if data:\n        result = data[0] * 2\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n\n    def enqueue(self, item):\n        self.items.append(item)\n\n    def dequeue(self):\n        return self.items.pop(0)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Additional rows
additional_data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection"],
    "Code Changes": [
        "if x < 5:\n    result = x / 2\nelse:\n    result = x - 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM transactions\")"
    ]
}

# Append additional rows to the DataFrame
df = df.append(pd.DataFrame(additional_data), ignore_index=True)

# Write the updated DataFrame to an Excel file
df.to_excel("1test_dataset_updated.xlsx", index=False, engine='openpyxl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 29
#      20 additional_data = {
#      21     "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection"],
#      22     "Code Changes": [
#    (...)
#      25     ]
#      26 }
#      28 # Append additional rows to the DataFrame
# ---> 29 df = df.append(pd.DataFrame(additional_data), ignore_index=True)
#      31 # Write the updated DataFrame to an Excel file
#      32 df.to_excel("1test_dataset_updated.xlsx", index=False, engine='openpyxl')
#
# File c:\Users\warun\anaconda3\envs\tensorflow\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
# ...

# %%
import pandas as pd

# Define the dataset
data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection", "Historical Failure Selection", "Coverage-Driven Selection", "Impact Analysis Selection", "Priority Queue Selection"],
    "Code Changes": [
        "if x > 5:\n    result = x * 2\nelse:\n    result = x + 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM users\")",
        "def divide(a, b):\n    return a / b\n\ndef test_divide():\n    assert divide(4, 2) == 2\n    assert divide(1, 0) == 0",
        "class Calculator:\n    def add(self, a, b):\n        return a + b\n\ndef test_add():\n    calc = Calculator()\n    assert calc.add(2, 3) == 5\n\ndef test_subtract():\n    calc = Calculator()\n    assert calc.subtract(5, 3) == 2",
        "def process_data(data):\n    if data:\n        result = data[0] * 2\n    else:\n        result = 0",
        "class Queue:\n    def __init__(self):\n        self.items = []\n\n    def enqueue(self, item):\n        self.items.append(item)\n\n    def dequeue(self):\n        return self.items.pop(0)\n\ndef test_enqueue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.items == [1]\n\ndef test_dequeue():\n    q = Queue()\n    q.enqueue(1)\n    assert q.dequeue() == 1"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("new1test_dataset.xlsx", index=False, engine='openpyxl')
import pandas as pd

# Define the dataset
data = {
    "Smart Test Selection Mechanism": ["Changed Code Selection", "Dependency-Based Selection"],
    "Code Changes": [
        "if x < 5:\n    result = x / 2\nelse:\n    result = x - 3",
        "from database import connect_db\n\ndef get_user_data(user_id):\n    db = connect_db()\n    data = db.query(\"SELECT * FROM transactions\")"
    ]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Write the DataFrame to an Excel file
df.to_excel("new1test_dataset.xlsx", index=False, engine='openpyxl')
